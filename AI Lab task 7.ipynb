# %% [markdown]
# ### Name : Muhammad Irtaza
# ### Class : BSAI-3C
# ### Roll No : SU92-BSAIM-F24-174
# ### Task No : 07

# %%
graph = {
    'A': [('B', 1), ('C', 3)],
    'B': [('D', 1), ('E', 5)],
    'C': [('F', 2)],
    'D': [('G', 1)],
    'E': [('G', 2)],
    'F': [('G', 1)],
    'G': []
}

a = {
    'A': 6,
    'B': 4,
    'C': 4,
    'D': 2,
    'E': 2,
    'F': 2,
    'G': 0
}

def a_star(start, goal):
    open_list = [start]        
    g = {start: 0}            
    parent = {start: None}     

    while open_list:
        current = min(open_list, key=lambda x: g.get(x, 999) + a.get(x, 999))

        if current == goal:
            path = []
            while current:
                path.append(current)
                current = parent[current]
            path.reverse()
            print("Shortest Path:", path)
            return

        open_list.remove(current)

        for neighbor, cost in graph[current]:
            new_g = g[current] + cost

            if neighbor not in g or new_g < g[neighbor]:
                g[neighbor] = new_g
                parent[neighbor] = current
                if neighbor not in open_list:
                    open_list.append(neighbor)

    print("No Path Found!")
a_star('A', 'G')
# Out:
# Shortest Path: ['A', 'B', 'D', 'G']
