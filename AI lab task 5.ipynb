# %% [markdown]
# ### Name : Muhammad Irtaza
# ### Class : BSAI-3C
# ### Roll No : SU92-BSAIM-F24-174
# ### Task No : 05

# %%
def dfs_with_stack(graph, start):
    visited = set()        
    stack = [start]        

    print("🔍 Starting Depth-First Search (DFS) traversal:")

    while stack:
        node = stack.pop()  

        if node not in visited:
            print(f"➡️ Visiting: {node}")
            visited.add(node)

            for neighbor in reversed(graph[node]):
                if neighbor not in visited:
                    print(f"   ↪️ Adding neighbor to stack: {neighbor}")
                    stack.append(neighbor)

graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

dfs_with_stack(graph, 'A')
# Out:
# 🔍 Starting Depth-First Search (DFS) traversal:
# ➡️ Visiting: A
#    ↪️ Adding neighbor to stack: C
#    ↪️ Adding neighbor to stack: B
# ➡️ Visiting: B
#    ↪️ Adding neighbor to stack: E
#    ↪️ Adding neighbor to stack: D
# ➡️ Visiting: D
# ➡️ Visiting: E
#    ↪️ Adding neighbor to stack: F
# ➡️ Visiting: F
# ➡️ Visiting: C

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


class BinaryTree:
    def __init__(self, root):
        self.root = Node(root)

    def preorder(self, node):
        if node:
            print(node.value, end=" ")
            self.preorder(node.left)
            self.preorder(node.right)

    def inorder(self, node):
        if node:
            self.inorder(node.left)
            print(node.value, end=" ")
            self.inorder(node.right)

    def postorder(self, node):
        if node:
            self.postorder(node.left)
            self.postorder(node.right)
            print(node.value, end=" ")

tree = BinaryTree('A')
tree.root.left = Node('B')
tree.root.right = Node('C')
tree.root.left.left = Node('D')
tree.root.left.right = Node('E')
tree.root.right.left = Node('F')
tree.root.right.right = Node('G')

print("Preorder Traversal:")
tree.preorder(tree.root)

print("\nInorder Traversal:")
tree.inorder(tree.root)

print("\nPostorder Traversal:")
tree.postorder(tree.root)
# Out:
# Preorder Traversal:
# A B D E C F G
# Inorder Traversal:
# D B E A F C G
# Postorder Traversal:
# D E B F G C A
